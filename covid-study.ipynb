# %%
import pandas as pd

# %%
covid_file = "./time_series_covid19_confirmed_global.csv"

# %%
covid_timeseries = pd.read_csv(covid_file)

# %%
covid_timeseries.size, covid_timeseries.columns
# Out:
# (125766,
#  Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#         '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#         ...
#         '4/11/21', '4/12/21', '4/13/21', '4/14/21', '4/15/21', '4/16/21',
#         '4/17/21', '4/18/21', '4/19/21', '4/20/21'],
#        dtype='object', length=459))

# %%
covid_timeseries.head(2)
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  4/11/21  4/12/21  4/13/21  \
# 0        0        0        0        0  ...    57160    57242    57364
# 1        0        0        0        0  ...   128393   128518   128752
#
#    4/14/21  4/15/21  4/16/21  4/17/21  4/18/21  4/19/21  4/20/21
# 0    57492    57534    57612    57721    57793    57898    58037
# 1   128959   129128   129307   129456   129594   129694   129842
#
# [2 rows x 459 columns]

# %%
covid_timeseries.iloc[-10:-5, 39]
# Out:
# 264    37
# 265     0
# 266     0
# 267     0
# 268     0
# Name: 2/26/20, dtype: int64

# %%
covid_timeseries.loc[0:, ['Province/State', 'Country/Region']]
# Out:
#     Province/State      Country/Region
# 0              NaN         Afghanistan
# 1              NaN             Albania
# 2              NaN             Algeria
# 3              NaN             Andorra
# 4              NaN              Angola
# ..             ...                 ...
# 269            NaN             Vietnam
# 270            NaN  West Bank and Gaza
# 271            NaN               Yemen
# 272            NaN              Zambia
# 273            NaN            Zimbabwe
#
# [274 rows x 2 columns]

# %%
covid_timeseries.loc[covid_timeseries['Country/Region']=='Canada']
# Out:
#                Province/State Country/Region      Lat      Long  1/22/20  \
# 39                    Alberta         Canada  53.9333 -116.5765        0
# 40           British Columbia         Canada  53.7267 -127.6476        0
# 41           Diamond Princess         Canada   0.0000    0.0000        0
# 42             Grand Princess         Canada   0.0000    0.0000        0
# 43                   Manitoba         Canada  53.7609  -98.8139        0
# 44              New Brunswick         Canada  46.5653  -66.4619        0
# 45  Newfoundland and Labrador         Canada  53.1355  -57.6604        0
# 46      Northwest Territories         Canada  64.8255 -124.8457        0
# 47                Nova Scotia         Canada  44.6820  -63.7443        0
# 48                    Nunavut         Canada  70.2998  -83.1076        0
# 49                    Ontario         Canada  51.2538  -85.3232        0
# 50       Prince Edward Island         Canada  46.5107  -63.4168        0
# ...

# %%
covid_timeseries.loc[(covid_timeseries['Country/Region']=='Canada') & (covid_timeseries['Province/State']=='Ontario')]
# Out:
#    Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 49        Ontario         Canada  51.2538 -85.3232        0        0        0
#
#     1/25/20  1/26/20  1/27/20  ...  4/11/21  4/12/21  4/13/21  4/14/21  \
# 49        0        1        1  ...   394197   398461   402003   406563
#
#     4/15/21  4/16/21  4/17/21  4/18/21  4/19/21  4/20/21
# 49   411346   416141   420241   424854   429240   432666
#
# [1 rows x 459 columns]

# %%
# Out:
#   File "<ipython-input-14-42921aef441e>", line 1
#     covid_timeseries."Country/Region"
#                      ^
# SyntaxError: invalid syntax
